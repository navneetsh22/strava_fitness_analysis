# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob
dfs = [pd.read_csv(file) for file in glob.glob("data/*.csv")]
for i, df in enumerate(dfs):
    print(f"\n📂 DataFrame {i+1}")
    print(dfs[i].dtypes)
# Load the dataset
